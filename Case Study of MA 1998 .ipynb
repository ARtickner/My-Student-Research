# %% [markdown]
# <a name="top"></a>
# <div style="width:1000 px">
#
# <div style="float:right; width:98 px; height:98px;">
# <img src="http://moziru.com/images/lightening-clipart-storm-cloud-10.png" alt="Thunderstorm" style="height: 98px;">
# </div>
# <h1>Case Study Template << (Ari Tickner)</h1>
#
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">
#
# https://en.wikipedia.org/wiki/Hurricane_Bonnie_(1998)
# ### Sections
# 1. <a href="#Introduction">Introduction</a>
# 1. <a href="#Rainfall">Rainfall Comparisons</a>
# 1. <a href="#Basics">Basic Synoptic and Mesoscale Flows</a>
# 1. <a href="#Moisture">Moisture Advection</a>
# 1. <a href="#Vertical">Vertical Structures</a>
# 1. <a href="#Summary">Summary and Conclusions</a>

# %% [markdown]
# First, let's load up the drilsdown extension:

# %%
# %reload_ext drilsdown 
#If you lose the control panel below, switch 'reload_ext' to 'make_ui'. Otherwise, keep as 'reload_ext as 
#all other commands to create images and movies and loading bundles will still work even without control panel.
# Out:
# VBox(children=(HTML(value='<h3>iPython-IDV Control Panel</h3>'), HBox(children=(HTML(value='<b>Resources:</b>'), Dropdown(options={'The Mapes IDV Collection': '45e3b50b-dbe2-408b-a6c2-2c009749cd53', 'Geode Systems Drilsdown Collection': '12704a38-9a06-4989-aac4-dafbbe13a675', 'NOAA-ESRL-PSD Climate Data Repository': 'f8d470f4-a072-4c1e-809e-d6116a393818', 'Unidata THREDDS Data Server': 'http://thredds.ucar.edu/thredds/catalog.xml', 'Unidata RAMADDA Server': '0', 'University of Miami THREDDS Data Server': 'http://weather.rsmas.miami.edu/thredds/catalog.xml', 'Local Files': '.'}, value='45e3b50b-dbe2-408b-a6c2-2c009749cd53'), Button(description='List', style=ButtonStyle(), tooltip='List'))), HBox(children=(HTML(value='<b>Search for:</b>'), Text(value='', layout=Layout(width='150px'), placeholder='IDV bundle'), Text(value='', layout=Layout(width='150px'), placeholder='Case Study or folder'), Text(value='', layout=Layout(width='150px'), placeholder='Gridded data files'), Text(value='', layout=Layout(width='150px'), placeholder='All'))), HBox(children=(Button(description='Run IDV', style=ButtonStyle(), tooltip='Run IDV'), Button(description='Make Image', style=ButtonStyle(), tooltip='Make Image'), Button(description='Make Movie', style=ButtonStyle(), tooltip='Make Movie'), Button(description='Save Bundle', style=ButtonStyle(), tooltip='Save Bundle'), Checkbox(value=False, description='Publish'))), HBox(children=(Button(description='Clear Outputs', style=ButtonStyle(), tooltip='Clear Outputs'), Button(description='Commands Help', style=ButtonStyle(), tooltip='Commands Help'), Label(value='')))))
# Starting IDV: C:\Program Files\IDV_5.4u1\runIDV
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Anaconda3\envs\MPO624\lib\site-packages\drilsdown\drilsdown.py in run_idv_clicked(b)
#     414     @staticmethod
#     415     def run_idv_clicked(b):
# --> 416         Idv.run_idv(from_user=True)
#     417
#     418     @staticmethod
#
# ~\Anaconda3\envs\MPO624\lib\site-packages\drilsdown\drilsdown.py in run_idv(from_user)
#     647         print("Starting IDV: " + path)
#     648         cwd = os.path.dirname(path)
# --> 649         subprocess.Popen([path], cwd=cwd)
#     650
#     651     # Give the IDV a chance to get going
#
# ~\Anaconda3\envs\MPO624\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     707                                 c2pread, c2pwrite,
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#     711             # Cleanup if the child failed starting.
#
# ~\Anaconda3\envs\MPO624\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#     995                                          env,
#     996                                          os.fspath(cwd) if cwd is not None else None,
# --> 997                                          startupinfo)
#     998             finally:
#     999                 # Child is launched. Close the parent's copy of those pipe
#
# OSError: [WinError 193] %1 is not a valid Win32 application

# %% [markdown]
# <a name="Introduction"></a>
# # 1. Introduction
#
# This is the introduction section. Introduce the case study with relevant articles that pertain to the socioeconomic impacts.

# %% [markdown]
# Text goes here.

# %% [markdown]
# <hr style="height:2px;">
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Rainfall"></a>
# # 2. Rainfall Characteristics
#
# This section highlights the different rainfall estimates from the 1-degree observational and reanalysis products. The key commands to launch the python script are below, and the command will output a 16-panel plot.

# %%
# %matplotlib inline
import warnings; warnings.filterwarnings('ignore')
# %run NASANEWS_teleport.py -ds yyyy-mm-dd -de yyyy-mm-dd -bbox S N W E -case name

#As an example:
#%run NASANEWS_teleport.py -ds 2005-07-23 -de 2005-07-27 -bbox 11 21 68 78 -case Maharashtra_Jul2005_Flood

# %% [markdown]
# Text goes here.

# %% [markdown]
# <hr style="height:2px;">
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Basics"></a>
# # 3. Basic Synoptic and Mesoscale Flows
#
# This section is where you can start to describe the broader scale synoptic and mesoscale flows associated with a case. Using these <code>make_image</code> and <code>make_movie</code> commands, images and animations can be extracted from the IDV. For animations, the loops will be based on the length of the time driver.

# %%
# %make_image -caption 'Cape Cod Heaviest Rain 1998...' -capture legend

# %%
# %make_image -caption 'Place your caption here...' -capture legend

# %%
# %make_image -caption 'Place your caption here...' -capture legend

# %%
# %make_movie -caption 'Place your caption here...' -capture legend

# %%
# %make_movie -caption 'Place your caption here...' -capture legend

# %%
# %make_movie -caption 'Place your caption here...' -capture legend

# %% [markdown]
# Text goes here.

# %% [markdown]
# <hr style="height:2px;">
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Moisture"></a>
# # 4. Moisture Advection
#
# This section should focus on the moisture component of the case study, one of the three principal components to sustained convection. As before, use the <code>make_image</code> and <code>make_movie</code> commands to select your images and loops.

# %%
# %make_image -caption 'Place your caption here...' -capture legend

# %%
# %make_image -caption 'Place your caption here...' -capture legend

# %%
# %make_image -caption 'Place your caption here...' -capture legend

# %%
# %make_movie -caption 'Place your caption here...' -capture legend

# %%
# %make_movie -caption 'Place your caption here...' -capture legend

# %%
# %make_movie -caption 'Place your caption here...' -capture legend

# %% [markdown]
# Text goes here.

# %% [markdown]
# <hr style="height:2px;">
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Vertical"></a>
# # 5. Vertical Structures
#
# This section should focus on the vertical cross sections of the case study that are carefully placed over the heavy rain event for clarity of explanation. This section should help to explain the dynamics and lift aspect of the case study (<i>i.e. the other two ingredients along with lift</i>).

# %%
# %make_image -caption 'Place your caption here...' -capture legend

# %%
# %make_image -caption 'Place your caption here...' -capture legend

# %%
# %make_image -caption 'Place your caption here...' -capture legend

# %%
# %make_movie -caption 'Place your caption here...' -capture legend

# %%
# %make_movie -caption 'Place your caption here...' -capture legend

# %%
# %make_movie -caption 'Place your caption here...' -capture legend

# %% [markdown]
# Text goes here.

# %% [markdown]
# <hr style="height:2px;">
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Summary"></a>
# # 6. Summary and Conclusions
#
# Wrap up the case study in this section detailing the most important findings.

# %% [markdown]
# Text goes here.

# %% [markdown]
# <hr style="height:2px;">
# <a href="#top">Top</a>
# <hr style="height:2px;">
